# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

ibm_left = pd.read_csv("IBM_HR_ATTRITION.csv")

# %%
ibm_left
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sns.catplot(data=ibm_left,
    x="Attrition", y="JobSatisfaction", kind="bar")

plt.show()

# %% [raw]
# seaborn.catplot(data=None, *, x=None, y=None, hue=None, row=None, col=None, col_wrap=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, height=5, aspect=1, kind='strip', native_scale=False, formatter=None, orient=None, color=None, palette=None, hue_norm=None, legend='auto', legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, ci='deprecated', **kwargs)

# %% [raw]
# seaborn.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)

# %%
sns.boxplot(data=ibm_left,
    x="Attrition", y="JobSatisfaction")

plt.show()

# %%
ibm_left.JobSatisfaction.describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
ibm_left.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sns.boxplot(data=ibm_left,
    x="Attrition", y="TotalWorkingYears")

plt.show()

# %%
ibm_left.TotalWorkingYears.describe()
# Out:
# count    1470.000000
# mean       11.279592
# std         7.780782
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64

# %% [raw]
# Series.replace(to_replace=None, value=_NoDefault.no_default, *, inplace=False, limit=None, regex=False, method=_NoDefault.no_default)

# %%
ibm_left_mod_2 = ibm_left.Attrition.replace(to_replace=["Yes","No"], value=[1,0])

# %%
ibm_left_mod_2
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
ibm_left
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
educ = ibm_left["EducationField"].value_counts()

# %%
educ
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [raw]
# En utilisant un Histogramme, regardez la répartition du taux de départ par
# EducationField

# %%
sns.barplot(data=ibm_left,
    x="Attrition", y="EducationField")

plt.show()

# %%
ibm_left.Education.describe()
# Out:
# count    1470.000000
# mean        2.912925
# std         1.024165
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Education, dtype: float64

# %% [raw]
# Conclusions:
# - Plus les employés ont de la satisfaction dans leur emploi, moins il y a de départs.
# - Plus les gens ont de l'ancienneté, moins il y a de départs.
# - Les départs (attrition) en fonction du domaine d'étude des employées est plus forte pour les employés diplômés en RH, ont un diplôme technique ou Marketing. Moins pour les formés en médical, Domaine non défini et Sciences de la vie.
